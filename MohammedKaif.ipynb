# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedkaif0/Covid-19Tracker/blob/gh-pages/MohammedKaif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Male and Female Vaccination ratio for covid-19

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e5cbb98d-6d7d-40d4-a51d-e94a6d350248" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5cbb98d-6d7d-40d4-a51d-e94a6d350248">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid_vaccine_statewise.csv to covid_vaccine_statewise.csv

# %%
vaccination = pd.read_csv(r"./covid_vaccine_statewise.csv")

# %%
vaccination.head(20)
# Out:
#     Updated On  State  ...  60+ years (Age)  Total Doses Administered
# 0   16/01/2021  India  ...              NaN                     48276
# 1   17/01/2021  India  ...              NaN                     58604
# 2   18/01/2021  India  ...              NaN                     99449
# 3   19/01/2021  India  ...              NaN                    195525
# 4   20/01/2021  India  ...              NaN                    251280
# 5   21/01/2021  India  ...              NaN                    365965
# 6   22/01/2021  India  ...              NaN                    549381
# 7   23/01/2021  India  ...              NaN                    759008
# 8   24/01/2021  India  ...              NaN                    835058
# 9   25/01/2021  India  ...              NaN                   1277104
# 10  26/01/2021  India  ...              NaN                   1293784
# 11  27/01/2021  India  ...              NaN                   1726490
# ...

# %%
male = vaccination["Male(Individuals Vaccinated)"].sum() 
female = vaccination["Female(Individuals Vaccinated)"].sum()  
trans = vaccination["Transgender(Individuals Vaccinated)"].sum()
px.pie(names=["Male Vaccinated","Female Vaccinated","Trans Gender"],values=[male,female,trans],title="Male and Female Vaccinated ratio for Covid19")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cce164fe-8002-4900-bc61-baf452303b57" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cce164fe-8002-4900-bc61-baf452303b57")) {
#                     Plotly.newPlot(
#                         'cce164fe-8002-4900-bc61-baf452303b57',
# ...
